# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dt = pd.read_csv("HH4.csv")

# %%
dt.head(10)
# Out:
#    SNO             SNAME             STATE   BOARD  M1(ENGLISH)  M2(MATHS)  \
# 0    1     MUNISH THAKUR  HIMACHAL PRADESH  HPBOSE           85         89
# 1    2       JYOTI DHAKA  HIMACHAL PRADESH  HPBOSE           80         91
# 2    3   ANUSHKA CHAUHAN  HIMACHAL PRADESH  HPBOSE           88         90
# 3    4      SHIYA THAKUR  HIMACHAL PRADESH  HPBOSE           76         92
# 4    5      SHEETAL KOUR  HIMACHAL PRADESH  HPBOSE           69         67
# 5    6            UMAANG  HIMACHAL PRADESH  HPBOSE           90         78
# 6    7   SHIVKANSH SINGH  HIMACHAL PRADESH  HPBOSE           89         90
# 7    8     TARIK HUSSAIN  HIMACHAL PRADESH  HPBOSE           82         94
# 8    9  MANDAKINI MOITRA  HIMACHAL PRADESH  HPBOSE           71         76
# 9   10            OMNATH  HIMACHAL PRADESH  HPBOSE           75         73
#
#    M3(SST)  M4(Science)  M5(LOCAL LANGUAGE)  Total Marks  GENDER  AGE CASTE  \
# ...

# %%
dt = dt.drop(['SNO','SNAME','STATE'],axis = 1)

# %%
dt
# Out:
#       BOARD  M1(ENGLISH)  M2(MATHS)  M3(SST)  M4(Science)  M5(LOCAL LANGUAGE)  \
# 0    HPBOSE           85         89       90           97                  88
# 1    HPBOSE           80         91       76           66                  67
# 2    HPBOSE           88         90       67           65                  80
# 3    HPBOSE           76         92       78           92                  87
# 4    HPBOSE           69         67       69           93                  91
# ..      ...          ...        ...      ...          ...                 ...
# 474   APBSE           55         47       41           47                  47
# 475   MSBSE           53         68       60           65                  65
# 476    BSEB           45         65       63           65                  65
# 477    SEBA           67         45       50           47                  47
# 478    BESM           37         55       47           70                  70
#
# ...

# %%
dt.isnull().values.any()
# Out:
# False

# %%
dt.isnull().sum()
# Out:
# BOARD                    0
# M1(ENGLISH)              0
# M2(MATHS)                0
# M3(SST)                  0
# M4(Science)              0
# M5(LOCAL LANGUAGE)       0
# Total Marks              0
# GENDER                   0
# AGE                      0
# CASTE                    0
# CONTENT COVERAGE         0
# SUBJECTIVITY             0
# SOCIO-ECONOMIC FACTOR    0
# SELECTION                0
# dtype: int64

# %%
dt1=dt.dropna()

# %%
dt1
# Out:
#       BOARD  M1(ENGLISH)  M2(MATHS)  M3(SST)  M4(Science)  M5(LOCAL LANGUAGE)  \
# 0    HPBOSE           85         89       90           97                  88
# 1    HPBOSE           80         91       76           66                  67
# 2    HPBOSE           88         90       67           65                  80
# 3    HPBOSE           76         92       78           92                  87
# 4    HPBOSE           69         67       69           93                  91
# ..      ...          ...        ...      ...          ...                 ...
# 474   APBSE           55         47       41           47                  47
# 475   MSBSE           53         68       60           65                  65
# 476    BSEB           45         65       63           65                  65
# 477    SEBA           67         45       50           47                  47
# 478    BESM           37         55       47           70                  70
#
# ...

# %%
dt1.isnull().sum()
# Out:
# BOARD                    0
# M1(ENGLISH)              0
# M2(MATHS)                0
# M3(SST)                  0
# M4(Science)              0
# M5(LOCAL LANGUAGE)       0
# Total Marks              0
# GENDER                   0
# AGE                      0
# CASTE                    0
# CONTENT COVERAGE         0
# SUBJECTIVITY             0
# SOCIO-ECONOMIC FACTOR    0
# SELECTION                0
# dtype: int64

# %%
pd.crosstab(dt1['BOARD'],dt['SELECTION']).plot(kind='bar',stacked = True)
# Out:
# <Axes: xlabel='BOARD'>

# %%
pd.crosstab(dt1['M5(LOCAL LANGUAGE)'],dt['SELECTION']).plot(kind='bar',stacked = True)
# Out:
# <Axes: xlabel='M5(LOCAL LANGUAGE)'>

# %%
sns.violinplot(
    x = 'GENDER',
    y = 'SELECTION',
    showmeans=True,
    data=dt1
)

plt.show()

# %%
pd.crosstab(dt1['GENDER'],dt['SELECTION']).plot(kind='bar',stacked = True)
# Out:
# <Axes: xlabel='GENDER'>

# %%
pd.crosstab(dt1['CONTENT COVERAGE'],dt['SELECTION']).plot(kind='bar',stacked = True)
# Out:
# <Axes: xlabel='CONTENT COVERAGE'>

# %%
pd.crosstab(dt1['SUBJECTIVITY'],dt['SELECTION']).plot(kind='bar',stacked = True)
# Out:
# <Axes: xlabel='SUBJECTIVITY'>

# %%
pd.crosstab(dt1['SOCIO-ECONOMIC FACTOR'],dt['SELECTION']).plot(kind='bar',stacked = True)
# Out:
# <Axes: xlabel='SOCIO-ECONOMIC FACTOR'>

# %%
plt.figure(figsize=(30,14))
sns.heatmap(dt.corr(),annot=True,cmap='Reds')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8636\620825118.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dt.corr(),annot=True,cmap='Reds')
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
x = dt1.drop('SELECTION', axis=1)
y = dt1['SELECTION']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
print("Training set shape:", x_train.shape)
print("Testing set shape:", x_test.shape)
# Out:
# Training set shape: (383, 13)
# Testing set shape: (96, 13)

# %%
#support vector classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
x_train_encoded = encoder.fit_transform(x_train)
x_test_encoded = encoder.transform(x_test)
decisiontree = DecisionTreeClassifier(random_state=0)
decisiontree.fit(x_train_encoded, y_train)
y_pred = decisiontree.predict(x_test_encoded)
acc_decisiontree_classifier = round(accuracy_score(y_pred, y_test), 2) * 100
print("ACCURACY:", acc_decisiontree_classifier)
# Out:
# ACCURACY: 93.0
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
x_train_encoded = encoder.fit_transform(x_train)
x_test_encoded = encoder.transform(x_test)

logreg = LogisticRegression(max_iter=100)
logreg.fit(x_train_encoded, y_train)
y_pred = logreg.predict(x_test_encoded)

acc_logreg = round(accuracy_score(y_pred, y_test), 2) * 100
print("ACCURACY:", acc_logreg)
# Out:
# ACCURACY: 99.0
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

base_model = DecisionTreeClassifier()

encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
x_train_encoded = encoder.fit_transform(x_train)
x_test_encoded = encoder.transform(x_test)

ensemble_model = BaggingClassifier(base_estimator=base_model, n_estimators=100)
ensemble_model.fit(x_train_encoded, y_train)

y_pred = ensemble_model.predict(x_test_encoded)
acc_ensemble_model = round(accuracy_score(y_pred, y_test), 2) * 100
print("ACCURACY:", acc_ensemble_model)
joblib.dump(ensemble_model, 'ensemble_model.pkl')
print("Model saved to ensemble_model.pkl")
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# ACCURACY: 94.0
# Model saved to ensemble_model.pkl

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
x_train_encoded = encoder.fit_transform(x_train)
x_test_encoded = encoder.transform(x_test)

svc = SVC(max_iter=100, gamma='auto')
svc.fit(x_train_encoded, y_train)

y_pred = svc.predict(x_test_encoded)
acc_svc = round(accuracy_score(y_pred, y_test), 2) * 100
print("ACCURACY:", acc_svc)
# Out:
# ACCURACY: 98.0
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
